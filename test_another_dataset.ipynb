# %%
import pandas as pd

# %%
df = pd.read_excel("air_quality_data_edited.xlsx")


df = df.drop(df.columns[0], axis=1)
df = df.iloc[:1018]
df
# Out:
#      Core Based Statistical Area Pollutant       Trend Statistic  \
# 0                     Adrian, MI        O3               4th Max
# 1                      Akron, OH        O3               4th Max
# 2                            NaN     PM2.5  Weighted Annual Mean
# 3                            NaN     PM2.5       98th Percentile
# 4                            NaN       SO2       99th Percentile
# ...                          ...       ...                   ...
# 1013               Yuba City, CA       NO2           Annual Mean
# 1014                         NaN       NO2       98th Percentile
# 1015                         NaN        O3               4th Max
# 1016                         NaN     PM2.5  Weighted Annual Mean
# 1017                         NaN     PM2.5       98th Percentile
#
#       Number of Trends Sites     2000     2001     2002     2003     2004  \
# 0                        1.0    0.082    0.086    0.089    0.088    0.074
# ...
